# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID           City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0        Rikitea      PF -23.1203 -134.9692     71.40        78
# 1        1  Mar Del Plata      AR -38.0023  -57.5575     46.87        79
# 2        2        Mataura      NZ -46.1927  168.8643     65.48        42
# 3        3          Sitka      US  57.0531 -135.3300     35.49        80
# 4        4       Crnomelj      SI  45.5711   15.1889     50.00        69
#
#    Cloudiness  Wind Speed       Description
# 0          69       24.74        light rain
# 1          40        4.61  scattered clouds
# 2         100        3.89   overcast clouds
# 3           0        5.75         clear sky
# 4          39        3.78  scattered clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
city_input_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)]
city_input_df.head(20)
# Out:
#     City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 0         0          Rikitea      PF -23.1203 -134.9692     71.40        78
# 2         2          Mataura      NZ -46.1927  168.8643     65.48        42
# 5         5        Carnarvon      AU -24.8667  113.6333     76.33        36
# 6         6          Caucaia      BR  -3.7361  -38.6531     79.03        76
# 13       13  Ambagarh Chauki      IN  20.7833   80.7167     76.35        55
# 15       15        Busselton      AU -33.6500  115.3333     63.86        59
# 16       16           Jieshi      CN  22.8134  115.8257     68.40        78
# 17       17       Butaritari      KI   3.0707  172.7902     81.36        76
# 19       19             Mega      ET   4.0500   38.3000     62.89        74
# 20       20   Cap Malheureux      MU -19.9842   57.6142     77.47        64
# 22       22             Hilo      US  19.7297 -155.0900     73.26        96
# 23       23            Gamba      GA  -2.6500   10.0000     76.08        93
# 24       24             Adwa      ET  14.1646   38.8955     65.21        30
# 27       27       Bredasdorp      ZA -34.5322   20.0403     60.35        70
# 31       31           Atuona      PF  -9.8000 -139.0333     76.82        72
# 33       33        Mount Isa      AU -20.7333  139.5000     82.17        18
# 34       34            Lagos      NG   6.5833    3.7500     77.32        95
# 35       35         Acapulco      MX  16.8634  -99.8901     76.82        88
# 37       37   Port Elizabeth      ZA -33.9180   25.5701     62.10        86
# 38       38           Yarada      IN  17.6500   83.2667     86.32        62
#
#     Cloudiness  Wind Speed       Description
# 0           69       24.74        light rain
# 2          100        3.89   overcast clouds
# 5            0       14.61         clear sky
# 6           40        8.05  scattered clouds
# 13           3        7.87         clear sky
# 15          98        5.01   overcast clouds
# 16         100       26.24     moderate rain
# 17          52       13.96     broken clouds
# 19           6        9.42         clear sky
# 20          17        8.99        few clouds
# 22         100        8.05     moderate rain
# 23         100        1.90   overcast clouds
# 24          54        3.09     broken clouds
# 27          13       20.62        few clouds
# 31           0       11.23         clear sky
# 33          13        8.05        few clouds
# 34          32        2.28  scattered clouds
# 35          20        2.30        few clouds
# 37           0        8.05         clear sky
# 38          40        5.75              haze

# %%
# 4a. Determine if there are any empty rows.
city_input_df.isnull().count()
# Out:
# City_ID        363
# City           363
# Country        363
# Lat            363
# Lng            363
# Max Temp       363
# Humidity       363
# Cloudiness     363
# Wind Speed     363
# Description    363
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = city_input_df.dropna()
clean_df.count()
# Out:
# City_ID        363
# City           363
# Country        363
# Lat            363
# Lng            363
# Max Temp       363
# Humidity       363
# Cloudiness     363
# Wind Speed     363
# Description    363
# dtype: int64

# %%
import numpy as np 
import ipywidgets as widgets 

# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#                 City Country  Max Temp       Description      Lat       Lng  \
# 0            Rikitea      PF     71.40        light rain -23.1203 -134.9692
# 2            Mataura      NZ     65.48   overcast clouds -46.1927  168.8643
# 5          Carnarvon      AU     76.33         clear sky -24.8667  113.6333
# 6            Caucaia      BR     79.03  scattered clouds  -3.7361  -38.6531
# 13   Ambagarh Chauki      IN     76.35         clear sky  20.7833   80.7167
# ..               ...     ...       ...               ...      ...       ...
# 682      Salinopolis      BR     80.24   overcast clouds  -0.6136  -47.3561
# 684         Veracruz      MX     68.41  scattered clouds  19.3333  -96.6667
# 685       Amalapuram      IN     80.29   overcast clouds  16.5833   82.0167
# 686      Niquelandia      BR     70.92   overcast clouds -14.4739  -48.4597
# 687       Devaprayag      IN     78.75         clear sky  30.1500   78.6167
#
#     Hotel Name
# 0
# 2
# 5
# 6
# 13
# ..         ...
# 682
# 684
# 685
# 686
# 687
#
# [363 rows x 7 columns]

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index,row in hotel_df.iterrows():

    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found....skipping")
# Out:
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping

# %%
hotel_df.head(35)
# Out:
#                City Country  Max Temp       Description      Lat       Lng  \
# 0           Rikitea      PF     71.40        light rain -23.1203 -134.9692
# 2           Mataura      NZ     65.48   overcast clouds -46.1927  168.8643
# 5         Carnarvon      AU     76.33         clear sky -24.8667  113.6333
# 6           Caucaia      BR     79.03  scattered clouds  -3.7361  -38.6531
# 13  Ambagarh Chauki      IN     76.35         clear sky  20.7833   80.7167
# 15        Busselton      AU     63.86   overcast clouds -33.6500  115.3333
# 16           Jieshi      CN     68.40     moderate rain  22.8134  115.8257
# 17       Butaritari      KI     81.36     broken clouds   3.0707  172.7902
# 19             Mega      ET     62.89         clear sky   4.0500   38.3000
# 20   Cap Malheureux      MU     77.47        few clouds -19.9842   57.6142
# 22             Hilo      US     73.26     moderate rain  19.7297 -155.0900
# 23            Gamba      GA     76.08   overcast clouds  -2.6500   10.0000
# 24             Adwa      ET     65.21     broken clouds  14.1646   38.8955
# 27       Bredasdorp      ZA     60.35        few clouds -34.5322   20.0403
# 31           Atuona      PF     76.82         clear sky  -9.8000 -139.0333
# 33        Mount Isa      AU     82.17        few clouds -20.7333  139.5000
# 34            Lagos      NG     77.32  scattered clouds   6.5833    3.7500
# 35         Acapulco      MX     76.82        few clouds  16.8634  -99.8901
# 37   Port Elizabeth      ZA     62.10         clear sky -33.9180   25.5701
# 38           Yarada      IN     86.32              haze  17.6500   83.2667
# 40     Puerto Ayora      EC     67.37   overcast clouds  -0.7393  -90.3518
# 42            Kapaa      US     80.58  scattered clouds  22.0752 -159.3190
# 45        Mahebourg      MU     79.09  scattered clouds -20.4081   57.7000
# 47        Bathsheba      BB     83.01  scattered clouds  13.2167  -59.5167
# 49         Xinxiang      CN     69.17         clear sky  35.3089  113.8672
# 56         Chipiona      ES     61.30              mist  36.7366   -6.4370
# 59          Itarema      BR     78.04     broken clouds  -2.9248  -39.9167
# 61     Vila Do Maio      CV     77.79   overcast clouds  15.1333  -23.2167
# 65       Kaitangata      NZ     68.65   overcast clouds -46.2817  169.8464
# 70          Hualmay      PE     61.00         clear sky -11.0964  -77.6139
# 71       Carutapera      BR     79.66   overcast clouds  -1.1950  -46.0200
# 74          Bacolod      PH     86.54        few clouds  10.6667  122.9500
# 75       Morant Bay      JM     78.42        light rain  17.8815  -76.4093
# 78      Grand Gaube      MU     79.20        few clouds -20.0064   57.6608
# 80        El Sauzal      MX     65.82   overcast clouds  31.9000 -116.6833
#
#                               Hotel Name
# 0                        People ThankYou
# 2                          Ellie's Villa
# 5                  Hospitality Carnarvon
# 6    M.O.S. Logística - Filial Fortaleza
# 13       गाँधी चौक शांति भवन सोनसाय टोला
# 15               Observatory Guest House
# 16                          Yuehai Hotel
# 17                    Isles Sunset Lodge
# 19                   Amanuel Guest House
# 20                 Pereybere Hotel & Spa
# 22                   Hilo Hawaiian Hotel
# 23
# 24                       Maay Assa Hotel
# 27              Bredasdorp Country Manor
# 31                           Villa Enata
# 33             ibis Styles Mt Isa Verona
# 34
# 35             HS Hotsson Smart Acapulco
# 37                39 On Nile Guest House
# 38           Yarada Jungle Beach Resorts
# 40             Finch Bay Galapagos Hotel
# 42   Sheraton Kauai Coconut Beach Resort
# 45    Shandrani Beachcomber Resort & Spa
# 47                        Atlantis Hotel
# 49                     Guoyu Holiday Inn
# 56                    Al Sur De Chipiona
# 59    Sea Lounge! Bar, Club & Restaurant
# 61                          Hotel Marilu
# 65                 Kaitangata Motor Camp
# 70             Hotel Villa Kitzia Huacho
# 71                                Lidera
# 74             Planta Hotel & Residences
# 75         Whispering Bamboo Cove Resort
# 78  Veranda Paul et Virginie Hotel & Spa
# 80                 Hotel Las Rosas & Spa

# %%
# Insert 'NaN' into empty 'hotel name' cells
hotel_df.loc[hotel_df["Hotel Name"] == ''] = np.nan

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df.head(35)
# Out:
#                City Country  Max Temp       Description      Lat       Lng  \
# 0           Rikitea      PF     71.40        light rain -23.1203 -134.9692
# 2           Mataura      NZ     65.48   overcast clouds -46.1927  168.8643
# 5         Carnarvon      AU     76.33         clear sky -24.8667  113.6333
# 6           Caucaia      BR     79.03  scattered clouds  -3.7361  -38.6531
# 13  Ambagarh Chauki      IN     76.35         clear sky  20.7833   80.7167
# 15        Busselton      AU     63.86   overcast clouds -33.6500  115.3333
# 16           Jieshi      CN     68.40     moderate rain  22.8134  115.8257
# 17       Butaritari      KI     81.36     broken clouds   3.0707  172.7902
# 19             Mega      ET     62.89         clear sky   4.0500   38.3000
# 20   Cap Malheureux      MU     77.47        few clouds -19.9842   57.6142
# 22             Hilo      US     73.26     moderate rain  19.7297 -155.0900
# 23              NaN     NaN       NaN               NaN      NaN       NaN
# 24             Adwa      ET     65.21     broken clouds  14.1646   38.8955
# 27       Bredasdorp      ZA     60.35        few clouds -34.5322   20.0403
# 31           Atuona      PF     76.82         clear sky  -9.8000 -139.0333
# 33        Mount Isa      AU     82.17        few clouds -20.7333  139.5000
# 34              NaN     NaN       NaN               NaN      NaN       NaN
# 35         Acapulco      MX     76.82        few clouds  16.8634  -99.8901
# 37   Port Elizabeth      ZA     62.10         clear sky -33.9180   25.5701
# 38           Yarada      IN     86.32              haze  17.6500   83.2667
# 40     Puerto Ayora      EC     67.37   overcast clouds  -0.7393  -90.3518
# 42            Kapaa      US     80.58  scattered clouds  22.0752 -159.3190
# 45        Mahebourg      MU     79.09  scattered clouds -20.4081   57.7000
# 47        Bathsheba      BB     83.01  scattered clouds  13.2167  -59.5167
# 49         Xinxiang      CN     69.17         clear sky  35.3089  113.8672
# 56         Chipiona      ES     61.30              mist  36.7366   -6.4370
# 59          Itarema      BR     78.04     broken clouds  -2.9248  -39.9167
# 61     Vila Do Maio      CV     77.79   overcast clouds  15.1333  -23.2167
# 65       Kaitangata      NZ     68.65   overcast clouds -46.2817  169.8464
# 70          Hualmay      PE     61.00         clear sky -11.0964  -77.6139
# 71       Carutapera      BR     79.66   overcast clouds  -1.1950  -46.0200
# 74          Bacolod      PH     86.54        few clouds  10.6667  122.9500
# 75       Morant Bay      JM     78.42        light rain  17.8815  -76.4093
# 78      Grand Gaube      MU     79.20        few clouds -20.0064   57.6608
# 80        El Sauzal      MX     65.82   overcast clouds  31.9000 -116.6833
#
#                               Hotel Name
# 0                        People ThankYou
# 2                          Ellie's Villa
# 5                  Hospitality Carnarvon
# 6    M.O.S. Logística - Filial Fortaleza
# 13       गाँधी चौक शांति भवन सोनसाय टोला
# 15               Observatory Guest House
# 16                          Yuehai Hotel
# 17                    Isles Sunset Lodge
# 19                   Amanuel Guest House
# 20                 Pereybere Hotel & Spa
# 22                   Hilo Hawaiian Hotel
# 23                                   NaN
# 24                       Maay Assa Hotel
# 27              Bredasdorp Country Manor
# 31                           Villa Enata
# 33             ibis Styles Mt Isa Verona
# 34                                   NaN
# 35             HS Hotsson Smart Acapulco
# 37                39 On Nile Guest House
# 38           Yarada Jungle Beach Resorts
# 40             Finch Bay Galapagos Hotel
# 42   Sheraton Kauai Coconut Beach Resort
# 45    Shandrani Beachcomber Resort & Spa
# 47                        Atlantis Hotel
# 49                     Guoyu Holiday Inn
# 56                    Al Sur De Chipiona
# 59    Sea Lounge! Bar, Club & Restaurant
# 61                          Hotel Marilu
# 65                 Kaitangata Motor Camp
# 70             Hotel Villa Kitzia Huacho
# 71                                Lidera
# 74             Planta Hotel & Residences
# 75         Whispering Bamboo Cove Resort
# 78  Veranda Paul et Virginie Hotel & Spa
# 80                 Hotel Las Rosas & Spa

# %%
clean_hotel_df = hotel_df.dropna()
clean_hotel_df.head(35)
# Out:
#                City Country  Max Temp       Description      Lat       Lng  \
# 0           Rikitea      PF     71.40        light rain -23.1203 -134.9692
# 2           Mataura      NZ     65.48   overcast clouds -46.1927  168.8643
# 5         Carnarvon      AU     76.33         clear sky -24.8667  113.6333
# 6           Caucaia      BR     79.03  scattered clouds  -3.7361  -38.6531
# 13  Ambagarh Chauki      IN     76.35         clear sky  20.7833   80.7167
# 15        Busselton      AU     63.86   overcast clouds -33.6500  115.3333
# 16           Jieshi      CN     68.40     moderate rain  22.8134  115.8257
# 17       Butaritari      KI     81.36     broken clouds   3.0707  172.7902
# 19             Mega      ET     62.89         clear sky   4.0500   38.3000
# 20   Cap Malheureux      MU     77.47        few clouds -19.9842   57.6142
# 22             Hilo      US     73.26     moderate rain  19.7297 -155.0900
# 24             Adwa      ET     65.21     broken clouds  14.1646   38.8955
# 27       Bredasdorp      ZA     60.35        few clouds -34.5322   20.0403
# 31           Atuona      PF     76.82         clear sky  -9.8000 -139.0333
# 33        Mount Isa      AU     82.17        few clouds -20.7333  139.5000
# 35         Acapulco      MX     76.82        few clouds  16.8634  -99.8901
# 37   Port Elizabeth      ZA     62.10         clear sky -33.9180   25.5701
# 38           Yarada      IN     86.32              haze  17.6500   83.2667
# 40     Puerto Ayora      EC     67.37   overcast clouds  -0.7393  -90.3518
# 42            Kapaa      US     80.58  scattered clouds  22.0752 -159.3190
# 45        Mahebourg      MU     79.09  scattered clouds -20.4081   57.7000
# 47        Bathsheba      BB     83.01  scattered clouds  13.2167  -59.5167
# 49         Xinxiang      CN     69.17         clear sky  35.3089  113.8672
# 56         Chipiona      ES     61.30              mist  36.7366   -6.4370
# 59          Itarema      BR     78.04     broken clouds  -2.9248  -39.9167
# 61     Vila Do Maio      CV     77.79   overcast clouds  15.1333  -23.2167
# 65       Kaitangata      NZ     68.65   overcast clouds -46.2817  169.8464
# 70          Hualmay      PE     61.00         clear sky -11.0964  -77.6139
# 71       Carutapera      BR     79.66   overcast clouds  -1.1950  -46.0200
# 74          Bacolod      PH     86.54        few clouds  10.6667  122.9500
# 75       Morant Bay      JM     78.42        light rain  17.8815  -76.4093
# 78      Grand Gaube      MU     79.20        few clouds -20.0064   57.6608
# 80        El Sauzal      MX     65.82   overcast clouds  31.9000 -116.6833
# 82         Souillac      MU     79.18  scattered clouds -20.5167   57.5167
# 85        Sinnamary      GF     78.73   overcast clouds   5.3833  -52.9500
#
#                               Hotel Name
# 0                        People ThankYou
# 2                          Ellie's Villa
# 5                  Hospitality Carnarvon
# 6    M.O.S. Logística - Filial Fortaleza
# 13       गाँधी चौक शांति भवन सोनसाय टोला
# 15               Observatory Guest House
# 16                          Yuehai Hotel
# 17                    Isles Sunset Lodge
# 19                   Amanuel Guest House
# 20                 Pereybere Hotel & Spa
# 22                   Hilo Hawaiian Hotel
# 24                       Maay Assa Hotel
# 27              Bredasdorp Country Manor
# 31                           Villa Enata
# 33             ibis Styles Mt Isa Verona
# 35             HS Hotsson Smart Acapulco
# 37                39 On Nile Guest House
# 38           Yarada Jungle Beach Resorts
# 40             Finch Bay Galapagos Hotel
# 42   Sheraton Kauai Coconut Beach Resort
# 45    Shandrani Beachcomber Resort & Spa
# 47                        Atlantis Hotel
# 49                     Guoyu Holiday Inn
# 56                    Al Sur De Chipiona
# 59    Sea Lounge! Bar, Club & Restaurant
# 61                          Hotel Marilu
# 65                 Kaitangata Motor Camp
# 70             Hotel Villa Kitzia Huacho
# 71                                Lidera
# 74             Planta Hotel & Residences
# 75         Whispering Bamboo Cove Resort
# 78  Veranda Paul et Virginie Hotel & Spa
# 80                 Hotel Las Rosas & Spa
# 82           Shanti Maurice Resort & Spa
# 85        ALETHEIA Appartement Sinnamary

# %%
hotel_df.count()
# Out:
# City           338
# Country        338
# Max Temp       338
# Description    338
# Lat            338
# Lng            338
# Hotel Name     338
# dtype: int64

# %%
# 8a. Create the output File (CSV)
output_data_file = "../Vacation_Search/WeatherPy_vacation.csv"

# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature 
# for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
locations = clean_hotel_df[["Lat", "Lng"]]
max_temp = clean_hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
